# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %%
# Import dataset
Netflix = pd.read_csv(r"C:\Users\parva\Downloads\Python Projects\netflix_titles.csv")

# %%
# View data
Netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# DATA WRANGLING

# %%
# shows first 5 rows
Netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#shows last 5 rows
Netflix.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# shows no: of rows & cols
Netflix.shape
# Out:
# (8807, 12)

# %%
# size = rows * cols
Netflix.size
# Out:
# 105684

# %%
#show header names
Netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# shows data type of each column
Netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# From the row counts there are some null values in this dataset no. 3-9

# %%
#shows duplicate rows in data
Netflix[Netflix.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# Finding NULL values
Netflix.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
# shows total null values in the dataset
Netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#using seaborn to vizualize the nullvalues in the data set
import matplotlib.pyplot as plt
sns.heatmap(Netflix.isnull())
plt.show()

# %%
# drop rows which contains missing value

# %%
C_Netflix = Netflix.dropna()

# %%
#Using the isin() statement to filter the key word
Netflix[Netflix['title'].isin(['Jaws'])]
# Out:
#    show_id   type title          director  \
# 41     s42  Movie  Jaws  Steven Spielberg
#
#                                                  cast        country  \
# 41  Roy Scheider, Robert Shaw, Richard Dreyfuss, L...  United States
#
#             date_added  release_year rating duration  \
# 41  September 16, 2021          1975     PG  124 min
#
#                                      listed_in  \
# 41  Action & Adventure, Classic Movies, Dramas
#
#                                           description
# 41  When an insatiable great white shark terrorize...

# %%
#Using the str.contains() to filter key word
Netflix[Netflix['title'].str.contains('Jaws')]
# Out:
#    show_id   type              title          director  \
# 41     s42  Movie               Jaws  Steven Spielberg
# 42     s43  Movie             Jaws 2    Jeannot Szwarc
# 43     s44  Movie             Jaws 3         Joe Alves
# 44     s45  Movie  Jaws: The Revenge    Joseph Sargent
#
#                                                  cast        country  \
# 41  Roy Scheider, Robert Shaw, Richard Dreyfuss, L...  United States
# 42  Roy Scheider, Lorraine Gary, Murray Hamilton, ...  United States
# 43  Dennis Quaid, Bess Armstrong, Simon MacCorkind...  United States
# 44  Lorraine Gary, Lance Guest, Mario Van Peebles,...  United States
#
#             date_added  release_year rating duration  \
# 41  September 16, 2021          1975     PG  124 min
# 42  September 16, 2021          1978     PG  116 min
# 43  September 16, 2021          1983     PG   98 min
# 44  September 16, 2021          1987  PG-13   91 min
#
#                                        listed_in  \
# ...

# %%
# 1.What year were the higest no. of shows and movie released?

# %%
Netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# convert release columns into Datetime
Netflix['date']=pd.to_datetime(Netflix['date_added'])

# %%
Netflix.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# date            datetime64[ns]
# dtype: object

# %%
# the value_counts()function helps to count distinct values in the mentioned col
Netflix['date'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: date, dtype: int64

# %%
# Year 2019 has the highest number of movies and show releases with 2016 in total

# %%
Using a Bar chart

# %%
Netflix['date'].dt.year.value_counts().plot(kind ='bar', color= 'navy') 
plt.title("Frequency of Release Year", fontsize=20)
plt.xlabel("Year", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.show()

# %%
# 2.How many movies and tv shows are in the dataset?

# %%
Netflix.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data = Netflix, x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
# 3.What movies where released in year 2010?

# %%
Netflix['year'] = Netflix['date'].dt.year
Netflix[(Netflix['type']== 'Movie') & (Netflix['year']== 2010)]  #Filtering
# Out:
#      show_id   type                        title    director  \
# 7370   s7371  Movie  Mad Ron's Prevues from Hell  Jim Monaco
#
#                                                    cast        country  \
# 7370  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#             date_added  release_year rating duration  \
# 7370  November 1, 2010          1987     NR   84 min
#
#                        listed_in  \
# 7370  Cult Movies, Horror Movies
#
#                                             description       date    year
# 7370  This collection cherry-picks trailers, forgott... 2010-11-01  2010.0

# %%
# 4. List TV shows released in

# %%
Netflix [(Netflix['type']== 'TV Show') & (Netflix['country']== 'Nigeria')] #Filtering
# Out:
#      show_id     type                                 title      director  \
# 49       s50  TV Show                     Castle and Castle           NaN
# 198     s199  TV Show  King of Boys: The Return of the King  Kemi Adetiba
# 1654   s1655  TV Show                             Before 30     BB Sasore
# 2102   s2103  TV Show                      Ojos in d' House           NaN
# 2148   s2149  TV Show                          The Governor           NaN
# 2906   s2907  TV Show                           On the Real   Tosin Coker
# 2938   s2939  TV Show                     Fifty: The Series           NaN
# 2992   s2993  TV Show                 Sons of the Caliphate           NaN
# 3130   s3131  TV Show                   Crazy, Lovely, Cool  Obi Emelonye
#
#                                                    cast  country  \
# 49    Richard Mofe-Damijo, Dakore Akande, Bimbo Manu...  Nigeria
# 198   Sola Sobowale, Toni Tones, Richard Mofe-Damijo...  Nigeria
# ...

# %%
Netflix [(Netflix['type']== 'TV Show') & (Netflix['country']== 'Nigeria')] ['title'] #filtering Titles only
# Out:
# 49                         Castle and Castle
# 198     King of Boys: The Return of the King
# 1654                               Before 30
# 2102                        Ojos in d' House
# 2148                            The Governor
# 2906                             On the Real
# 2938                       Fifty: The Series
# 2992                   Sons of the Caliphate
# 3130                     Crazy, Lovely, Cool
# Name: title, dtype: object

# %%
# 5.Top 10 Directors with the highest no. of TV shows and Movies released on Netflix

# %%
Netflix['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
#Plot the bar chart
plt.figure(figsize=(10,4))
Netflix['director'].value_counts().head(15).plot(kind='bar', color='cyan').set_title('Top 15 Directors With highest Movies & TV shows on Netflix', fontsize=13)
plt.show()

# %%
# 6. List comedy movies and movie released in Germany

# %%
Netflix [(Netflix['type']== 'Movie') & (Netflix['listed_in']== 'Comedies') | (Netflix['country']== 'Germany')]
# Out:
#      show_id   type                          title                 director  \
# 27       s28  Movie                      Grown Ups             Dennis Dugan
# 152     s153  Movie  Janoskians: Untold and Untrue             Brett Weiner
# 182     s183  Movie    Welcome Home Roscoe Jenkins           Malcolm D. Lee
# 342     s343  Movie                    Major Payne              Nick Castle
# 348     s349  Movie                           Poms               Zara Hayes
# ...      ...    ...                            ...                      ...
# 8440   s8441  Movie                The NSU-Complex  Stefan Aust, Dirk Laabs
# 8453   s8454  Movie                  The Physician           Philipp Stölzl
# 8536   s8537  Movie              The Trip to Spain     Michael Winterbottom
# 8608   s8609  Movie               Total Frat Movie         Warren P. Sonoda
# 8730   s8731  Movie              Where's the Money          Scott Zabielski
#
# ...

# %%
# 7.How many movies and TVshows was Brad Pitt cast in?

# %%
# note: Clean null value rows from data before run this.
C_Netflix[C_Netflix['cast'].str.contains('Brad Pitt')]
# Out:
#      show_id   type                       title               director  \
# 630     s631  Movie         Killing Them Softly         Andrew Dominik
# 2903   s2904  Movie                  By the Sea         Angelina Jolie
# 5473   s5474  Movie                 War Machine           David Michôd
# 5942   s5943  Movie  A Stoning in Fulham County          Larry Elikann
# 6205   s6206  Movie                       Babel  Alejandro G. Iñárritu
# 7077   s7078  Movie        Inglourious Basterds      Quentin Tarantino
# 7638   s7639  Movie            Ocean's Thirteen      Steven Soderbergh
# 7639   s7640  Movie              Ocean's Twelve      Steven Soderbergh
#
#                                                    cast  \
# 630   Brad Pitt, Scoot McNairy, Ben Mendelsohn, Rich...
# 2903  Angelina Jolie, Brad Pitt, Mélanie Laurent, Me...
# 5473  Brad Pitt, Topher Grace, Emory Cohen, John Mag...
# 5942  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
# ...

# %%
# 8.What are the diffrent ratings defined by Netflix?

# %%
# no.of unique rating
Netflix.rating.nunique()
# Out:
# 17

# %%
Netflix.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
# 9.How Many Movie has the "PG" Rating before 2015 ?

# %%
Netflix [(Netflix['rating']== 'PG') &(Netflix['year']< 2015)]
# Out:
#      show_id   type                                      title  \
# 5937   s5938  Movie                             The Short Game
# 5941   s5942  Movie          Being Elmo: A Puppeteer's Journey
# 6840   s6841  Movie                                  Get Santa
# 7097   s7098  Movie  Iron Man & Captain America: Heroes United
# 7415   s7416  Movie    Marvel's Iron Man & Hulk: Heroes United
#
#                       director  \
# 5937            Josh Greenbaum
# 5941           Constance Marks
# 6840         Christopher Smith
# 7097                 Leo Riley
# 7415  Leo Riley, Eric Radomski
#
#                                                    cast  \
# 5937  Sky Sudberry, Allan Kournikova, Jed Dy, Zamoku...
# 5941                       Kevin Clash, Whoopi Goldberg
# 6840  Jodie Whittaker, Warwick Davis, Jim Broadbent,...
# 7097  Adrian Pasdar, Roger Craig Smith, Fred Tatasci...
# 7415  Adrian Pasdar, Fred Tatasciore, Dee Bradley Ba...
#
# ...

# %%
# 10.Find the maximum duration of a Movie or Show in Netflix?

# %%
Netflix[['minutes','unit']]= Netflix['duration'].str.split(' ', expand = True)

# %%
Netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
Netflix.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# date            datetime64[ns]
# year                   float64
# Minutes                 object
# Unit                    object
# minutes                 object
# unit                    object
# min                    float64
# dtype: object

# %%
# convert data type
Netflix['min'] = pd.to_numeric(Netflix['minutes'])

# %%
# Convert data type to integer/float to calculate max()
Netflix['min'].max()
# Out:
# 312.0

# %%
# 11.Which Country has the highest no. of TV shows

# %%
filter1 = Netflix[Netflix['type']== 'TV Show']

# %%
filter1.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description       date    year  \
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
# 2  To protect his family from a powerful drug lor... 2021-09-24  2021.0
#
#   Minutes     Unit minutes     unit  min
# ...

# %%
filter1['country'].value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
Netflix['country'].value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
#Plot Bar
plt.figure(figsize=(10,4))
sns.countplot(x='country', data = Netflix, order = Netflix['country'].value_counts().head().index)
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.title("Top 5 Movie released Countries", fontsize=15)
plt.show()

# %%
# Sort the Dataset by year

# %%
Netflix.sort_values(by = 'year').head(2)
# Out:
#      show_id     type                 title              director  \
# 5957   s5958    Movie  To and From New York  Sorin Dan Mihalcescu
# 6611   s6612  TV Show       Dinner for Five                   NaN
#
#                                                    cast        country  \
# 5957  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 6611                                                NaN  United States
#
#             date_added  release_year rating  duration  \
# 5957   January 1, 2008          2006  TV-MA    81 min
# 6611  February 4, 2008          2007  TV-MA  1 Season
#
#                                   listed_in  \
# 5957  Dramas, Independent Movies, Thrillers
# 6611           Stand-Up Comedy & Talk Shows
#
#                                             description       date    year  \
# 5957  While covering a story in New York City, a Sea... 2008-01-01  2008.0
# 6611  In each episode, four celebrities join host Jo... 2008-02-04  2008.0
#
# ...

# %%
Netflix.sort_values(by = 'year', ascending = False).head(2)
# Out:
#     show_id   type                 title         director  \
# 0        s1  Movie  Dick Johnson Is Dead  Kirsten Johnson
# 996    s997  Movie            HOMUNCULUS  Takashi Shimizu
#
#                                                   cast        country  \
# 0                                                  NaN  United States
# 996  Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...          Japan
#
#              date_added  release_year rating duration  \
# 0    September 25, 2021          2020  PG-13   90 min
# 996      April 22, 2021          2021  TV-MA  116 min
#
#                                           listed_in  \
# 0                                     Documentaries
# 996  Horror Movies, International Movies, Thrillers
#
#                                            description       date    year  \
# 0    As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 996  Truth and illusion blurs when a homeless amnes... 2021-04-22  2021.0
#
# ...

# %%
# 12.What is the best time of the year to release a movie/TV show?

# %%
#Add a new column called month, displaying only the month from the release date.
Netflix['month'] = pd.DatetimeIndex(Netflix['date']).month
Netflix. head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description       date    year  \
# 0  As her father nears the end of his life, filmm... 2021-09-25  2021.0
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24  2021.0
#
# ...

# %%
#Count the total number of movies and group by month.
Netflix.groupby(['month','type'])['type'].count()
# Out:
# month  type
# 1.0    Movie      546
#        TV Show    192
# 2.0    Movie      382
#        TV Show    181
# 3.0    Movie      529
#        TV Show    213
# 4.0    Movie      550
#        TV Show    214
# 5.0    Movie      439
#        TV Show    193
# 6.0    Movie      492
#        TV Show    236
# 7.0    Movie      565
#        TV Show    262
# 8.0    Movie      519
#        TV Show    236
# 9.0    Movie      519
#        TV Show    251
# 10.0   Movie      545
#        TV Show    215
# 11.0   Movie      498
#        TV Show    207
# 12.0   Movie      547
#        TV Show    266
# Name: type, dtype: int64
